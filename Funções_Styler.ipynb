# %%
import pandas as pd
import numpy as np

# %%
dados = pd.DataFrame({'ID': [1204, 3018, 9963, 1005, 5627],
                   'Idade': [np.nan, 32, 19, np.nan, 38],
                   'Salário': [3500.00, 4200.50, 2800.00, 5700.25, 4900.75]})

# %%
s_nan = dados.style.format({'Idade':'{:.0f}','Salário':'{:,.2f}'})\
                   .highlight_null(color='#F79747')
s_nan
# Out:
# <style type="text/css">
# #T_113e8_row0_col1, #T_113e8_row3_col1 {
#   background-color: #F79747;
# }
# </style>
# <table id="T_113e8" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_113e8_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_113e8_level0_col1" class="col_heading level0 col1" >Idade</th>
#       <th id="T_113e8_level0_col2" class="col_heading level0 col2" >Salário</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_113e8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_113e8_row0_col0" class="data row0 col0" >1204</td>
#       <td id="T_113e8_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_113e8_row0_col2" class="data row0 col2" >3,500.00</td>
#     </tr>
#     <tr>
#       <th id="T_113e8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_113e8_row1_col0" class="data row1 col0" >3018</td>
#       <td id="T_113e8_row1_col1" class="data row1 col1" >32</td>
#       <td id="T_113e8_row1_col2" class="data row1 col2" >4,200.50</td>
#     </tr>
#     <tr>
#       <th id="T_113e8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_113e8_row2_col0" class="data row2 col0" >9963</td>
#       <td id="T_113e8_row2_col1" class="data row2 col1" >19</td>
#       <td id="T_113e8_row2_col2" class="data row2 col2" >2,800.00</td>
#     </tr>
#     <tr>
#       <th id="T_113e8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_113e8_row3_col0" class="data row3 col0" >1005</td>
#       <td id="T_113e8_row3_col1" class="data row3 col1" >nan</td>
#       <td id="T_113e8_row3_col2" class="data row3 col2" >5,700.25</td>
#     </tr>
#     <tr>
#       <th id="T_113e8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_113e8_row4_col0" class="data row4 col0" >5627</td>
#       <td id="T_113e8_row4_col1" class="data row4 col1" >38</td>
#       <td id="T_113e8_row4_col2" class="data row4 col2" >4,900.75</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# O desafio é construir uma visualização que permita informar a quantidade e distribuição de pedidos por tipo de desconto. Isso irá permitir que os setores da empresa entendam a demanda de produtos em cada ação promocional.

# %%
df = pd.read_csv('loja_livro_filmes.csv')

## Preparar os dados
# Ter o DataFrame fazendo a contagem dos pedidos em cada categoria de desconto
df_descontos = pd.DataFrame(df['tipo_desconto'].value_counts())
# Ajustar o nome da coluna e index
df_descontos.columns = ['N° pedidos']
df_descontos.index.name = 'Tipo desconto'
# Coletamos a distribuição da quantidade de pedidos por porcentagem
porcentagem = df_descontos['N° pedidos'].to_numpy()
porcentagem = 100 * porcentagem/porcentagem.sum()
df_descontos['Distribuição de pedidos'] = porcentagem
df_descontos

## Criar a visualização
s_descontos = df_descontos.style
# Utilizar propriedades CSS para formatar a visualização
cabecalho = {
    'selector': 'th',
    'props': 'font-weight: bold; font-family: Arial; text-align: right; background-color: white; color: black;'
}
celulas = {
    'selector': 'td',
    'props': 'background-color: white; color: black;'
}
s_descontos.set_table_styles([cabecalho, celulas], overwrite=False)
# Aplicar a visualização de gráfico
# os parâmetros height e width permitem alterar a proporção do tamanho do gráfico em relação a padrão 100
s_descontos.format({'Distribuição de pedidos': '{:.2f} %'})\
           .bar(subset='Distribuição de pedidos', vmin = 0, vmax = 100.0, color = '#093364',
                height=50,width=60)
# Out:
# <style type="text/css">
# #T_7ec75 th {
#   font-weight: bold;
#   font-family: Arial;
#   text-align: right;
#   background-color: white;
#   color: black;
# }
# #T_7ec75 td {
#   background-color: white;
#   color: black;
# }
# #T_7ec75_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #093364 32.2%, transparent 32.2%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_7ec75_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #093364 16.7%, transparent 16.7%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_7ec75_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #093364 4.8%, transparent 4.8%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_7ec75_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #093364 3.6%, transparent 3.6%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_7ec75_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #093364 2.8%, transparent 2.8%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# </style>
# <table id="T_7ec75" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7ec75_level0_col0" class="col_heading level0 col0" >N° pedidos</th>
#       <th id="T_7ec75_level0_col1" class="col_heading level0 col1" >Distribuição de pedidos</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Tipo desconto</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7ec75_level0_row0" class="row_heading level0 row0" >Sem desconto</th>
#       <td id="T_7ec75_row0_col0" class="data row0 col0" >13259</td>
#       <td id="T_7ec75_row0_col1" class="data row0 col1" >53.66 %</td>
#     </tr>
#     <tr>
#       <th id="T_7ec75_level0_row1" class="row_heading level0 row1" >Cyber Monday</th>
#       <td id="T_7ec75_row1_col0" class="data row1 col0" >6865</td>
#       <td id="T_7ec75_row1_col1" class="data row1 col1" >27.78 %</td>
#     </tr>
#     <tr>
#       <th id="T_7ec75_level0_row2" class="row_heading level0 row2" >Black Friday</th>
#       <td id="T_7ec75_row2_col0" class="data row2 col0" >1975</td>
#       <td id="T_7ec75_row2_col1" class="data row2 col1" >7.99 %</td>
#     </tr>
#     <tr>
#       <th id="T_7ec75_level0_row3" class="row_heading level0 row3" >Liquidação</th>
#       <td id="T_7ec75_row3_col0" class="data row3 col0" >1471</td>
#       <td id="T_7ec75_row3_col1" class="data row3 col1" >5.95 %</td>
#     </tr>
#     <tr>
#       <th id="T_7ec75_level0_row4" class="row_heading level0 row4" >Data especial</th>
#       <td id="T_7ec75_row4_col0" class="data row4 col0" >1140</td>
#       <td id="T_7ec75_row4_col1" class="data row4 col1" >4.61 %</td>
#     </tr>
#   </tbody>
# </table>
