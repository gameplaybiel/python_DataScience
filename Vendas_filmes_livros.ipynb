# %%
import pandas as pd

# %%
df = pd.read_csv('/content/loja_livro_filmes.csv')

## Preparar os dados
# Agrupar a soma das unidades por pais e ordenar os valores
df_paises = df.groupby(['pais'])['unidades'].sum().nlargest(9).copy()
df_paises = df_paises.reset_index()

# Alterar os nomes das colunas e ajustar o ranqueamento
df_paises.columns = ['País', 'Unidades pedidas']
df_paises['Rank'] = df_paises.index + 1
df_paises.set_index('Rank', inplace=True)
df_paises

## Criar a visualização
s_pais = df_paises.style
# Formatar o texto para adicionar a unidade de medida
s_pais = s_pais.format({'Unidades pedidas': '{} prod'})
s_pais
# Out:
# <style type="text/css">
# </style>
# <table id="T_2a0af" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2a0af_level0_col0" class="col_heading level0 col0" >País</th>
#       <th id="T_2a0af_level0_col1" class="col_heading level0 col1" >Unidades pedidas</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Rank</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2a0af_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_2a0af_row0_col0" class="data row0 col0" >Argentina</td>
#       <td id="T_2a0af_row0_col1" class="data row0 col1" >5591 prod</td>
#     </tr>
#     <tr>
#       <th id="T_2a0af_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_2a0af_row1_col0" class="data row1 col0" >Equador</td>
#       <td id="T_2a0af_row1_col1" class="data row1 col1" >5566 prod</td>
#     </tr>
#     <tr>
#       <th id="T_2a0af_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_2a0af_row2_col0" class="data row2 col0" >Paraguai</td>
#       <td id="T_2a0af_row2_col1" class="data row2 col1" >5564 prod</td>
#     </tr>
#     <tr>
#       <th id="T_2a0af_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_2a0af_row3_col0" class="data row3 col0" >Peru</td>
#       <td id="T_2a0af_row3_col1" class="data row3 col1" >5550 prod</td>
#     </tr>
#     <tr>
#       <th id="T_2a0af_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_2a0af_row4_col0" class="data row4 col0" >Venezuela</td>
#       <td id="T_2a0af_row4_col1" class="data row4 col1" >5529 prod</td>
#     </tr>
#     <tr>
#       <th id="T_2a0af_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_2a0af_row5_col0" class="data row5 col0" >Colômbia</td>
#       <td id="T_2a0af_row5_col1" class="data row5 col1" >5504 prod</td>
#     </tr>
#     <tr>
#       <th id="T_2a0af_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_2a0af_row6_col0" class="data row6 col0" >Brasil</td>
#       <td id="T_2a0af_row6_col1" class="data row6 col1" >5473 prod</td>
#     </tr>
#     <tr>
#       <th id="T_2a0af_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_2a0af_row7_col0" class="data row7 col0" >Uruguai</td>
#       <td id="T_2a0af_row7_col1" class="data row7 col1" >5377 prod</td>
#     </tr>
#     <tr>
#       <th id="T_2a0af_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_2a0af_row8_col0" class="data row8 col0" >Chile</td>
#       <td id="T_2a0af_row8_col1" class="data row8 col1" >5304 prod</td>
#     </tr>
#   </tbody>
# </table>
